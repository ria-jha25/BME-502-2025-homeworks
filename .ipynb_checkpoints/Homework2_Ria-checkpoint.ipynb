# %% [markdown]
# <h1>Homework 2</h1>

# %% [markdown]
# #### Bayes' theorem:
# \begin{equation*}
# P(A|B) = \frac{P(B|A)P(A)}{P(B)} \\
# P(A|B): Posteior \\
# P(B|A): Likelihood \\
# P(A): Prior \\
# P(B): Marginal Probability \\
# \end{equation*}

# %% [markdown]
# # Question 1
# ### Read the following example and complete the exercises
#
# You are at the age of 21 and curious about if drinking alcohol would cause liver disease. You contacted a clinic site and got the following information.
#
# 1. Past data tells you that 10% of patients entering the clinic have liver disease (**Prior**).
#
# 2. Five percent of the clinic’s patients are alcoholics (**Marginal Probability**).
#
# 3. Among the patients diagnosed with liver disease, 15% are alcoholics (**Likelihood**).
#
# Now you wonder what is the probability of a patient from the clinic have liver disease given that the patient is alcoholic (**Posterior**)

# %% [markdown]
# ### 1.1
#
# #### If A represents the event of being an alcoholic patient in the clinic and L represents the event of being a patient with liver disease in the clinic, write the bayesian representation (P(A|B)) in the following cells

# %% [markdown]
# Posteria = P(L|A)

# %% [markdown]
# Prior = P(L) = 0.10

# %% [markdown]
# Likelihood = P(A|L) = 0.15

# %% [markdown]
# Marginal Probability = P(A) = 0.05

# %% [markdown]
# ### 1.2
#
# #### Define all the information available and calculate the posterior probability

# %%
prior = 0.10  # P(L) 
likelihood = 0.15  # P(A|L) 
marginal_probability = 0.05  # P(A) 

posterior = (likelihood * prior) / marginal_probability
println("Posterior P(L|A): $(round(posterior, digits=4))")
println("Probability of a patient having liver disease given that the patient is an alcoholic = $(round(posterior * 100, digits=2))%")
# Out:
# Posterior P(L|A): 0.3
# Probability of a patient having liver disease given that the patient is an alcoholic = 30.0%

# %% [markdown]
# # Question 2
# ### Read the following example and complete the exercises
# Shown by a <a href="https://pubmed.ncbi.nlm.nih.gov/34242764/#:~:text=The%20overall%20sensitivity%20of%20the,%25%20CI%2024.4%2D65.1">reaserch study</a>, the rapid antigen test for Covid has a sensitivity of 65.3% and a specificity of 99.9%. Assume 1% people have Covid. If randomly select a person and he/she tests positive using the rapid antigen test, what is the probability the person has Covid (posterior).

# %% [markdown]
# ### 2.1
#
# #### The probability of which event is considered marginal probability in this case? Define it in the first cell below and calculate it in the second cell below

# %% [markdown]
# The event is:

# %%
println("A person testing positive on the rapid antigen test")
# Out:
# A person testing positive on the rapid antigen test

# %%
# Marginal probability = (likelihood*prior)/posterior

sensitivity = 0.653  # P(Positive|Covid)
specificity = 0.999  # P(Negative|No Covid)
prevalence = 0.01    # P(Covid)


PPos = (sensitivity*prevalence) + ((1-specificity)*(1-prevalence))
println("Probability of a person testing positive on the rapid antigen test: $(round(PPos, digits=4))")
# Out:
# Probability of a person testing positive on the rapid antigen test: 0.0075

# %% [markdown]
# ### 2.2
#
# #### Define all the information and calculate the probability the randomly selected person has Covid

# %%
sensitivity = 0.653  # P(Positive|Covid)
specificity = 0.999  # P(Negative|No Covid)
prevalence = 0.01    # P(Covid)


PPos = (sensitivity*prevalence) + ((1-specificity)*(1-prevalence))

P_covid_given_positive = (sensitivity*prevalence)/PPos


println("Probability of having Covid given a positive test: $(round(P_covid_given_positive,digits=4))")
# Out:
# Probability of having Covid given a positive test: 0.8684

# %% [markdown]
# # Question 3
# ### <a href="https://juliastats.org/Distributions.jl/stable/starting/">This page</a> is the documentation for Distribution.jl and complete the exercies

# %% [markdown]
# ### 3.1
#
# #### Randomly draw 1000 samples from a normal distribution with mean = 5 and std = 2

# %%
using Pkg
Pkg.add("Distributions")
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\Ria\Downloads\Everything\School\Grad_Stony\BME502\JuliaNotebooks\BME-502-2025-homeworks\Project.toml`
#   No Changes to `C:\Users\Ria\Downloads\Everything\School\Grad_Stony\BME502\JuliaNotebooks\BME-502-2025-homeworks\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Ria\Downloads\Everything\School\Grad_Stony\BME502\JuliaNotebooks\BME-502-2025-homeworks\Project.toml`
#   No Changes to `C:\Users\Ria\Downloads\Everything\School\Grad_Stony\BME502\JuliaNotebooks\BME-502-2025-homeworks\Manifest.toml`

# %%
using Distributions

d = Normal(5, 2)
data = rand(d, 1000)
# Out:
# 1000-element Vector{Float64}:
#  5.57462644433372
#  2.6619570840291105
#  4.904047987564553
#  2.1024439104940718
#  3.9738185888124473
#  5.989450152686899
#  4.068386854043519
#  9.892102637354956
#  9.045042955912788
#  5.723600438718733
#  5.30380897657051
#  4.17655707498547
#  8.241955192556503
#  ⋮
#  2.663933473981117
#  4.447417931268329
#  6.4494982375211265
#  0.6598148452029138
#  2.30056730486763
#  5.061648366492084
#  3.6605188518465246
#  3.800330274923459
#  3.9373915902787195
#  7.306457083161558
#  3.485048260968777
#  8.519115479151733

# %% [markdown]
# ### 3.2
#
# #### Plot  the distribution above in a histogram

# %%
using Distributions
using Plots
d = Normal(5, 2)
data = rand(d, 1000)

p1 = histogram(data, bins=:auto, title="Histogram of Normal Distribution", xlabel="Value", ylabel="Frequency")
display(p1)

# %% [markdown]
# ### 3.3
#
# #### Plot  the same distribution and change the bins to 50

# %%
using Distributions
using Plots

p2 = histogram(data, bins=50, title="Histogram of Normal Distribution (50 bins)", xlabel="Value", ylabel="Frequency")
display(p2)

# %% [markdown]
# ### 3.4
#
# #### Choose a distribution other than normal distribution, Describe what it represents, and draw 1000 samples from the distribution and plot it using parameters of your choice

# %% [markdown]
# Which distribution do you pick:

# %% [markdown]
# What does the distribution represent?
#
# The Beta distribution is defined from 0 to 1, and is used to model probabilities of random samples with a specific trait or criteria. The below beta distributions are scaled to compare with normal distribution.

# %%
using Distributions
using Plots


beta_dist = Beta(4, 7)  # α = 4, β = 7

samples_beta = rand(beta_dist, 1000)
p3 = histogram(samples_beta*10, bins=50, title="Histogram of Beta(4, 7) Distribution", xlabel="Value", ylabel="Frequency", label="Beta(4, 7)")
display(p3)

# %% [markdown]
# ### 3.5
#
# #### Plot  the two distributions in the same plot

# %%
using Distributions
using Plots


# Plot histograms
p4 = histogram(samples_beta*10, bins=50, alpha=0.5, label="Scaled Beta(4, 7)", xlabel="Value", ylabel="Frequency", title="Histograms of Scaled Beta and Normal Distributions")
histogram!(p4, data, bins=50, alpha=0.5, label="Normal(5, 2)")

display(p4)

# %% [markdown]
# ### 3.6
#
# #### Draw 10000 samples from the two distributions separately and plot them in the same plot

# %%
samples_beta = rand(beta_dist, 10000)
samples_normal = rand(normal_dist, 10000)

histogram(samples_beta*10, bins=100, alpha=0.5, label="Beta(4, 7)")
histogram!(samples_normal, bins=100, alpha=0.5, label="Normal(5, 2)")
title!("Histograms of 10000 Samples")
xlabel!("Value")
ylabel!("Frequency")
